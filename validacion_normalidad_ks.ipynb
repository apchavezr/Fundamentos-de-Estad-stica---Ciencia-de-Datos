# %% [markdown]
# <a href="https://colab.research.google.com/github/apchavezr/Fundamentos-de-Estad-stica---Ciencia-de-Datos/blob/main/validacion_normalidad_ks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Validación de Supuestos: Normalidad con Kolmogorov-Smirnov

# %%
import numpy as np
from scipy.stats import kstest, norm
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Paso 1: Generar residuos simulados de un modelo

# %%
np.random.seed(42)
residuos = np.random.normal(loc=0, scale=1, size=100)
sns.histplot(residuos, kde=True)
plt.title('Distribución de residuos')
plt.show()

# %% [markdown]
# ### Paso 2: Aplicar prueba Kolmogorov-Smirnov

# %%
ks_stat, p_valor = kstest(residuos, 'norm')
print(f"Estadístico K-S: {ks_stat:.4f}")
print(f"p-valor: {p_valor:.4f}")
# Out:
# Estadístico K-S: 0.1036
# p-valor: 0.2181

# %% [markdown]
# ### Conclusión
# Si el p-valor > 0.05, se acepta que los residuos siguen una distribución normal.
